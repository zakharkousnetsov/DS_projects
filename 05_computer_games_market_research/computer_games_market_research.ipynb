# %% [markdown]
# <h1>Содержание проекта<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#✔-Комментарий-ревьюера-V.2" data-toc-modified-id="✔-Комментарий-ревьюера-V.2-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>✔ Комментарий ревьюера V.2</a></span></li></ul></li><li><span><a href="#-Комментарий-ревьюера" data-toc-modified-id="-Комментарий-ревьюера-1"><span class="toc-item-num">1&nbsp;&nbsp;</span> Комментарий ревьюера</a></span><ul class="toc-item"><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li><li><span><a href="#!!-Комментарий-ревьюера" data-toc-modified-id="!!-Комментарий-ревьюера-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>!! Комментарий ревьюера</a></span></li><li><span><a href="#👀-Комментарий-ревьюера" data-toc-modified-id="👀-Комментарий-ревьюера-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>👀 Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Комментарий студента</a></span></li><li><span><a href="#Комментарий-студента-" data-toc-modified-id="Комментарий-студента--1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Комментарий студента </a></span></li><li><span><a href="#Комментарий-студента-v1" data-toc-modified-id="Комментарий-студента-v1-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Комментарий студента v1</a></span></li></ul></li><li><span><a href="#Изучение-и-предобработка-данных" data-toc-modified-id="Изучение-и-предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Изучение и предобработка данных</a></span><ul class="toc-item"><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-студента-v1" data-toc-modified-id="Комментарий-студента-v1-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Комментарий студента v1</a></span></li><li><span><a href="#✔-Комментарий-ревьюера-V.2" data-toc-modified-id="✔-Комментарий-ревьюера-V.2-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>✔ Комментарий ревьюера V.2</a></span></li><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-студента-v1" data-toc-modified-id="Комментарий-студента-v1-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Комментарий студента v1</a></span></li><li><span><a href="#✔-Комментарий-ревьюера-V.2" data-toc-modified-id="✔-Комментарий-ревьюера-V.2-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>✔ Комментарий ревьюера V.2</a></span></li><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-студента-v1" data-toc-modified-id="Комментарий-студента-v1-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Комментарий студента v1</a></span></li><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-2.10"><span class="toc-item-num">2.10&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-2.11"><span class="toc-item-num">2.11&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Исследование-количества-выпущенных-игр-по-годам" data-toc-modified-id="Исследование-количества-выпущенных-игр-по-годам-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Исследование количества выпущенных игр по годам</a></span></li><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-студента-v1" data-toc-modified-id="Комментарий-студента-v1-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Комментарий студента v1</a></span></li><li><span><a href="#Исследование-продаж-по-платформам" data-toc-modified-id="Исследование-продаж-по-платформам-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Исследование продаж по платформам</a></span></li><li><span><a href="#Исследование-динамики-продаж-по-платформам" data-toc-modified-id="Исследование-динамики-продаж-по-платформам-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Исследование динамики продаж по платформам</a></span></li><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-студента-v1" data-toc-modified-id="Комментарий-студента-v1-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Комментарий студента v1</a></span></li><li><span><a href="#✔-Комментарий-ревьюера-V.2" data-toc-modified-id="✔-Комментарий-ревьюера-V.2-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>✔ Комментарий ревьюера V.2</a></span></li><li><span><a href="#Анализ-динамики-популярности-платформ" data-toc-modified-id="Анализ-динамики-популярности-платформ-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Анализ динамики популярности платформ</a></span></li><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-3.10"><span class="toc-item-num">3.10&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-студента-v1" data-toc-modified-id="Комментарий-студента-v1-3.11"><span class="toc-item-num">3.11&nbsp;&nbsp;</span>Комментарий студента v1</a></span></li><li><span><a href="#✔-Комментарий-ревьюера-V.2" data-toc-modified-id="✔-Комментарий-ревьюера-V.2-3.12"><span class="toc-item-num">3.12&nbsp;&nbsp;</span>✔ Комментарий ревьюера V.2</a></span></li><li><span><a href="#Исследование-влияния-рейтингов-на-продажи" data-toc-modified-id="Исследование-влияния-рейтингов-на-продажи-3.13"><span class="toc-item-num">3.13&nbsp;&nbsp;</span>Исследование влияния рейтингов на продажи</a></span></li><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-3.14"><span class="toc-item-num">3.14&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li><li><span><a href="#Анализ-коммерческой-успешности-отдельных-жанров" data-toc-modified-id="Анализ-коммерческой-успешности-отдельных-жанров-3.15"><span class="toc-item-num">3.15&nbsp;&nbsp;</span>Анализ коммерческой успешности отдельных жанров</a></span></li><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-3.16"><span class="toc-item-num">3.16&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-студента-v1" data-toc-modified-id="Комментарий-студента-v1-3.17"><span class="toc-item-num">3.17&nbsp;&nbsp;</span>Комментарий студента v1</a></span></li><li><span><a href="#✔-Комментарий-ревьюера-V.2" data-toc-modified-id="✔-Комментарий-ревьюера-V.2-3.18"><span class="toc-item-num">3.18&nbsp;&nbsp;</span>✔ Комментарий ревьюера V.2</a></span></li></ul></li><li><span><a href="#Составление-портрета-пользователя-каждого-региона" data-toc-modified-id="Составление-портрета-пользователя-каждого-региона-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Составление портрета пользователя каждого региона</a></span><ul class="toc-item"><li><span><a href="#Анализ-популярности-платформ-в-регионах" data-toc-modified-id="Анализ-популярности-платформ-в-регионах-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Анализ популярности платформ в регионах</a></span></li><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li><li><span><a href="#✔-Комментарий-ревьюера-V.2" data-toc-modified-id="✔-Комментарий-ревьюера-V.2-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>✔ Комментарий ревьюера V.2</a></span></li><li><span><a href="#Комментарий-студента-v1" data-toc-modified-id="Комментарий-студента-v1-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Комментарий студента v1</a></span></li><li><span><a href="#Исследование-влияния-рейтинга-ESRB-на-продажи-в-отдельных-регионах" data-toc-modified-id="Исследование-влияния-рейтинга-ESRB-на-продажи-в-отдельных-регионах-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Исследование влияния рейтинга ESRB на продажи в отдельных регионах</a></span></li><li><span><a href="#✔-Комментарий-ревьюера" data-toc-modified-id="✔-Комментарий-ревьюера-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>✔ Комментарий ревьюера</a></span></li></ul></li><li><span><a href="#Проверка-гипотез" data-toc-modified-id="Проверка-гипотез-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Проверка гипотез</a></span><ul class="toc-item"><li><span><a href="#Гипотеза-1" data-toc-modified-id="Гипотеза-1-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Гипотеза 1</a></span></li><li><span><a href="#!!-Комментарий-ревьюера" data-toc-modified-id="!!-Комментарий-ревьюера-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>!! Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-студента-v1" data-toc-modified-id="Комментарий-студента-v1-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Комментарий студента v1</a></span></li><li><span><a href="#✔-Комментарий-ревьюера-V.2" data-toc-modified-id="✔-Комментарий-ревьюера-V.2-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>✔ Комментарий ревьюера V.2</a></span></li><li><span><a href="#Гипотеза-2" data-toc-modified-id="Гипотеза-2-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Гипотеза 2</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# # Исследование рынка компьютерных игр
#
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
#
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
#
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».
#
# Описание данных
# * Name — название игры
# * Platform — платформа
# * Year_of_Release — год выпуска
# * Genre — жанр игры
# * NA_sales — продажи в Северной Америке (миллионы проданных копий)
# * EU_sales — продажи в Европе (миллионы проданных копий)
# * JP_sales — продажи в Японии (миллионы проданных копий)
# * Other_sales — продажи в других странах (миллионы проданных копий)
# * Critic_Score — оценка критиков (максимум 100)
# * User_Score — оценка пользователей (максимум 10)
# * Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
#
# Данные за 2016 год могут быть неполными.

# %% [markdown]
# ##  Изучение и предобработка данных

# %%
# импорт необходимых для работы библиотек

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
import seaborn as sns
from scipy import stats as st
import warnings
import sys

def fxn():
    warnings.warn(message="there is something deprecated around here", category=DeprecationWarning)
    
#warnings.filterwarnings('ignore') # удаление всех ворнингов

# %%
# открытие датасета и сохранение его в переменную data

data = pd.read_csv('/datasets/games.csv')

# %% [markdown]
# Выведем общую информацию о датасете

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
# Name               16713 non-null object
# Platform           16715 non-null object
# Year_of_Release    16446 non-null float64
# Genre              16713 non-null object
# NA_sales           16715 non-null float64
# EU_sales           16715 non-null float64
# JP_sales           16715 non-null float64
# Other_sales        16715 non-null float64
# Critic_Score       8137 non-null float64
# User_Score         10014 non-null object
# Rating             9949 non-null object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# В наименовании столбцов вопреки общепринятым стандартам применена верблюжья нотация - имена необходимо поправить. Названия частей света в колонках с продажами по регионам лучше расшифровать:
# * NA - North America
# * EU - Europe
# * JP - Japan
#
# Среди значений датасета есть пропуски, которые нужно обработать, прежде чем приступать к анализу.

# %%
data.columns = data.columns.str.lower()
data.rename(columns={'na_sales': 'north_america_sales', 
                     'eu_sales': 'europe_sales', 
                     'jp_sales': 'japan_sales'}, inplace=True)

# %% [markdown]
# Заменим неявные пропуски данных в столбце с пользовательской оценкой. Аббревиатура `TBD` означает `to be defined`, что по содержанию равносильно `NaN`. Оценим количество подобных записей и заменим их на `NaN`.

# %%
#data.loc[data['user_score']=='tbd', 'user_score'] = np.NaN
data['user_score'] = pd.to_numeric(data['user_score'], errors='coerce')

# %% [markdown]
# Колонку `user_score` следует привести к типу `float`, чтобы иметь возможность совершать над ней математические операции.

# %%
data['user_score'] = data['user_score'].astype('float')

# %% [markdown]
# Добавим столбец с суммарными продажами игры

# %%
data.insert(data.columns.get_loc('other_sales')+1, 'total_sales', data['north_america_sales']+
                                                                  data['europe_sales']+
                                                                  data['japan_sales']+
                                                                  data['other_sales'])
data.sample(3)
# Out:
#                                    name platform  year_of_release       genre  \
# 5891   Pride FC: Fighting Championships      PS2           2003.0    Fighting
# 6185        Kenka Bancho: Badass Rumble      PSP           2008.0      Action
# 14923  Monster Mayhem: Build and Battle      Wii           2009.0  Simulation
#
#        north_america_sales  europe_sales  japan_sales  other_sales  \
# 5891                  0.15          0.11          0.0         0.04
# 6185                  0.06          0.00          0.2         0.01
# 14923                 0.02          0.00          0.0         0.00
#
#        total_sales  critic_score  user_score rating
# 5891          0.30          73.0         8.6      M
# 6185          0.27          70.0         7.5      T
# 14923         0.02           NaN         NaN   E10+

# %% [markdown]
# Посмотрим, игры каких категорий рейтинга ESRB представлены в датасете

# %%
display(data['rating'].unique())
display(data['rating'].value_counts())
# Out:
# array(['E', nan, 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'], dtype=object)
# E       3990
# T       2961
# M       1563
# E10+    1420
# EC         8
# RP         3
# K-A        3
# AO         1
# Name: rating, dtype: int64

# %% [markdown]
# Среди категорий есть `NaN`, которые лучше объединить под общим `unknown`, чтобы не искажать доли игр с определенным рейтингом. Игры с рейтингом EC, RP, K-A, AO в датасете всего несколько, поэтому выводы по ним не будут объективными. Тем не менее, терять эти записи тоже нежелательно, поэтому отнесем их также к `unknown`.

# %%
data.loc[data['rating'].isna(), 'rating'] = 'unknown'
data.loc[data['rating'].isin(['EC','RP','K-A','AO']), 'rating'] = 'unknown'

# %% [markdown]
# Основной задачей проекта является прогноз трендов на 2017 год. Рынок компьютерных игр очень динамичен, и тренды могут меняться довольно часто, поэтому чем дальше дата выхода игры от целевого года, тем меньше значимость этой записи для исследования. Пропуски в столбце с годом выпуска тоже внесут искажение в исследование, их можно было бы восстановить по данным из Интернета, но в рамках данного проектах придется опустить. Чтобы исследовать не только абсолютные значения, но и характер трендов (монотонный или переменный), возьмем период с 2000 года.

# %%
data_filtered = data.query('year_of_release>2000').reset_index(drop=True)

# %% [markdown]
# До фильтрации оставались необработанные данные. Возможно, проблемные записи не попали в новый датафрейм. Заново выведем основную информацию по датафрейму.

# %%
data_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14120 entries, 0 to 14119
# Data columns (total 12 columns):
# name                   14120 non-null object
# platform               14120 non-null object
# year_of_release        14120 non-null float64
# genre                  14120 non-null object
# north_america_sales    14120 non-null float64
# europe_sales           14120 non-null float64
# japan_sales            14120 non-null float64
# other_sales            14120 non-null float64
# total_sales            14120 non-null float64
# critic_score           7744 non-null float64
# user_score             7264 non-null float64
# rating                 14120 non-null object
# dtypes: float64(8), object(4)
# memory usage: 1.3+ MB

# %% [markdown]
# Ранее колонку `year_of_release` нельзя было привести к целочисленному типу по причине наличия `Nan`. Сделаем это сейчас

# %%
data_filtered['year_of_release'] = data_filtered['year_of_release'].astype('int')

# %% [markdown]
# Нулевые продажи могут означать отсутствие локализованной версии игры для одного из рынков, но если суммарные продажи равны нулю, такие записи стоит исключит из исследования

# %%
data_filtered = data_filtered.query('total_sales!=0').reset_index(drop=True)

# %% [markdown]
# Добавим информацию о факте выхода игры на рынок каждого из регионов

# %%
data_filtered.insert(data_filtered.columns.get_loc('genre')+1, 
                     'released_in_north_america', 
                      data_filtered['north_america_sales'].transform(lambda x: 0 if x==0 else 1).astype('bool'))

data_filtered.insert(data_filtered.columns.get_loc('genre')+2, 
                     'released_in_europe', 
                      data_filtered['europe_sales'].transform(lambda x: 0 if x==0 else 1).astype('bool'))

data_filtered.insert(data_filtered.columns.get_loc('genre')+3, 
                     'released_in_japan', 
                      data_filtered['japan_sales'].transform(lambda x: 0 if x==0 else 1).astype('bool'))

# %% [markdown]
# Исследуем датасет на предмет статистического разнообразия. Сильно выбивающиеся данные не позволят сделать корректные выводы о тенденциях.

# %%
data_filtered.describe()
# Out:
#        year_of_release  north_america_sales  europe_sales   japan_sales  \
# count     14118.000000         14118.000000  14118.000000  14118.000000
# mean       2008.221207             0.243314      0.143989      0.054756
# std           3.960796             0.718488      0.517672      0.246800
# min        2001.000000             0.000000      0.000000      0.000000
# 25%        2005.000000             0.000000      0.000000      0.000000
# 50%        2008.000000             0.080000      0.020000      0.000000
# 75%        2011.000000             0.220000      0.110000      0.030000
# max        2016.000000            41.360000     28.960000      6.500000
#
#         other_sales   total_sales  critic_score   user_score
# count  14118.000000  14118.000000   7744.000000  7264.000000
# mean       0.050750      0.492810     68.849819     7.104777
# std        0.200471      1.475134     13.832910     1.498659
# min        0.000000      0.010000     13.000000     0.000000
# ...

# %% [markdown]
# Судя по максимальным значениям числа проданных копий, в данных действительно есть выбросы. Их удобнее всего увидеть на диаграмме размаха и подтвердить гистограммой. Забегая вперед, ограничим сверху число проданных копий и посмотрим, какой вид после удаления от выбросов приобреди диаграмма размаха и гистограмма

# %%
with warnings.catch_warnings():
    fxn()
    warnings.simplefilter("ignore")
    
    
    plt.figure(figsize=(18, 8))

    sales_max = 3
    bins = 100
    alpha = 0.5

    ax = plt.subplot(1,3,1)
    pd.DataFrame(data = {'Северная Америка': data_filtered['north_america_sales'], 
                         'Европа': data_filtered['europe_sales'], 
                         'Япония': data_filtered['japan_sales']}).plot.box(ax=ax);
    plt.title('Диаграмма размаха до фильтраци')
    plt.ylabel('Число проданных копий');

    ax = plt.subplot(1,3,2)
    pd.DataFrame(data = {'Северная Америка': data_filtered.query('north_america_sales<@sales_max')['north_america_sales'], 
                         'Европа': data_filtered.query('europe_sales<@sales_max')['europe_sales'], 
                         'Япония': data_filtered.query('japan_sales<@sales_max')['japan_sales']}).plot.box(ax=ax);
    plt.title('Диаграмма размаха после фильтрации')
    plt.ylabel('Число проданных копий');

    ax = plt.subplot(1,3,3)
    plt.ylim([0, 1200])
    data_filtered.query('north_america_sales<@sales_max')['north_america_sales'].plot(kind='hist', bins=bins, alpha=alpha)
    data_filtered.query('europe_sales<@sales_max')['europe_sales'].plot(kind='hist', bins=bins, ax=ax, alpha=alpha);
    data_filtered.query('japan_sales<@sales_max')['japan_sales'].plot(kind='hist', bins=bins, ax=ax, alpha=alpha);
    ax.legend(['Северная Америка', 'Европа', 'Япония'])
    plt.title('Гистограмма после фильтрации')
    plt.xlabel('Число проданных копий');
    plt.ylabel('Частота встречаемости значения');

    #plt.tight_layout()
    #plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:13: DeprecationWarning: there is something deprecated around here
#   del sys.path[0]

# %% [markdown]
# Судя по присутствию выбросов даже на очищенной диаграмме размаха, порог можно было бы сделать еще ниже. Однако дальнейшее сокращение исследуемого диапазона чревато выпадением из поля зрения некоторых популярных видеоигр, а рекомендации, полученные на основе анализа игр средней популярности, вряд ли заинтересуют заказчика.
#
# Рассчитаем количество выбросов для каждого из рынков

# %%
print('При выбранном пороговом значении =', 
      sales_max, 
      'для рынка Северной Америки будет отброшено', 
      data_filtered.query('north_america_sales>@sales_max')['north_america_sales'].count(), 
      'значений')

print('При выбранном пороговом значении =', 
      sales_max, 
      'для рынка Европы будет отброшено', 
      data_filtered.query('europe_sales>@sales_max')['europe_sales'].count(), 
      'значений')

print('При выбранном пороговом значении =', 
      sales_max, 
      'для рынка Японии будет отброшено', 
      data_filtered.query('japan_sales>@sales_max')['japan_sales'].count(), 
      'значений')
# Out:
# При выбранном пороговом значении = 3 для рынка Северной Америки будет отброшено 102 значений
# При выбранном пороговом значении = 3 для рынка Европы будет отброшено 60 значений
# При выбранном пороговом значении = 3 для рынка Японии будет отброшено 26 значений

# %% [markdown]
# Итак, принимаем решение исключить из исследования 100-200 сверхпопулярных игр. Будем считать, что принятая граница количества продаж позволяет нам найти баланс между репрезентативностью датасета и наличием в нем ценных данных.

# %%
data_filtered = data_filtered.query('north_america_sales<@sales_max and europe_sales<@sales_max and japan_sales<@sales_max').reset_index(drop=True)

# %% [markdown]
# Пока отсутствие версии игры для одного из регионов выражено нулем, статистические данные искажаются. В данном случае будет не совсем правильным сказать, что количество проданных версий равно нулю - игра даже не продавалась. Поэтому заменим нули в колонках с продажами игр на `NaN`.

# %%
data_filtered.loc[data_filtered['north_america_sales']==0, 'north_america_sales'] = np.NaN
data_filtered.loc[data_filtered['europe_sales']==0, 'europe_sales'] = np.NaN
data_filtered.loc[data_filtered['japan_sales']==0, 'japan_sales'] = np.NaN
data_filtered.loc[data_filtered['other_sales']==0, 'other_sales'] = np.NaN

# %% [markdown]
# Остались пропуски только в колонках `critic_score`, `user_score`, `rating`. Заполнение их любыми синтетическими данными (средней, медианой, наиболее часто повторяющимся значением и т.д.) не добавит исследованию объективности. Убедимся, что для каждого исследуемого года в колонках с рейтингом достаточно данных.

# %%
data_filtered.groupby('year_of_release')[['critic_score','user_score','rating']].count()
# Out:
#                  critic_score  user_score  rating
# year_of_release
# 2001                      320         251     475
# 2002                      623         460     824
# 2003                      584         515     773
# 2004                      554         482     753
# 2005                      650         578     933
# 2006                      612         544     997
# 2007                      679         616    1183
# 2008                      707         653    1417
# 2009                      640         603    1413
# 2010                      487         454    1239
# 2011                      492         493    1127
# 2012                      312         330     643
# 2013                      268         299     536
# 2014                      256         323     572
# 2015                      223         295     601
# 2016                      231         261     501

# %% [markdown]
# Итак, по каждому году есть не менее двухсот оценок по каждому из каналов, этого будет достаточно для качественного исследования.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Исследование количества выпущенных игр по годам

# %% [markdown]
# Исследуем исторические данные об объемах выпуска компьютерных игр. Заодно сравним очищенный датасет с сырым и проверим верность выдвинутой гипотезы о достаточном для исследования временном промежутке.

# %%
ax = data.groupby('year_of_release')['year_of_release'].count().plot(figsize=(16,7), style='-o')
data_filtered.groupby('year_of_release')['year_of_release'].count().plot(ax=ax, style='-o');
plt.title('Количество выпущенных игр в разные годы');
plt.xlabel('Год выпуска')
plt.ylabel('Количество выпущенных игр')
ax.legend(['Оригинальные данные', 'Очищенные данные']);

# %% [markdown]
# По графику видно, что рост популярности видеоигр начался в начале девяностых, и после небольшой рецессии новое тысячелетие началось со взрывного роста рынка. Эта точка совпадает с датой выхода первых игр из отфильтрованного датасета. Кризис 2008 года коснулся и игровой индустрии. На момент формирования датасета объем выпускаемых игр был на уровне 2001 года.
#
# Хотя, разумеется, стоит сделать поправку на то, что исходный датасет наверняка содержит неполную информацию, и выводы о количестве выпущенных игр только по количеству игр в датасете были бы искажены из-за "ошибки выжившего".

# %% [markdown]
# ### Исследование продаж по платформам

# %% [markdown]
# Рассмотрим распределение продаж по платформам и выделим группу наиболее популярных платформ. Для этого обратимся к данным из неочищенного датасета, содержащего сведения начиная с 1980 года.

# %%
plt.figure(figsize=(7,8))

plt.barh(data.groupby('platform')['total_sales'].sum().sort_values()[:-6].index, 
         data.groupby('platform')['total_sales'].sum().sort_values()[:-6].values,
         label = 'Малые платформы')

plt.barh(data.groupby('platform')['total_sales'].sum().sort_values()[-6:].index, 
         data.groupby('platform')['total_sales'].sum().sort_values()[-6:].values, 
         label = 'Крупные платформы')

plt.title('Суммарные продажи игр для каждой платформы')
plt.xlabel('Число проданных копий, млн')
plt.ylabel('Платформа')

handles,labels = plt.gca().get_legend_handles_labels()
handles = [handles[1], handles[0]]
labels = [labels[1], labels[0]]
plt.legend(handles, labels, loc='lower right');

# %% [markdown]
# Выделяется группа из шести лидеров. Однако некоторые из них, такие как PS2, уже могли сдать позиции. Поэтому дальнейший анализ по платформам нужно будет вести, опираясь на данные начиная с 2001 года.

# %% [markdown]
# ### Исследование динамики продаж по платформам

# %% [markdown]
# Тренды невечны, и сегодняшние хиты обязательно рано или поздно утратят популярность. Восстановим хронологию становления и заката десяти самых популярных (если верить полноте датасета) за всю историю платформ.

# %%
top_platforms = list(data.groupby('platform')['total_sales'].sum().sort_values().tail(10).index)

data.query('platform.isin(@top_platforms)').pivot_table(index='year_of_release', 
                          columns='platform', 
                          values='total_sales', 
                          aggfunc='sum').plot(figsize=(16, 7), style='-');
plt.title('Динамика роста игровых платформ');
plt.xlabel('Год выпуска');
plt.ylabel('Количество проданных игр, млн');

# %% [markdown]
# За исключением персональных компьютеров, все самые популярные платформы просуществовали около десяти лет.

# %%
plt.subplots(figsize=(16,8)) 
sns.heatmap(data.query('platform.isin(@top_platforms)').pivot_table(index='platform', 
                                                                    columns='year_of_release', 
                                                                    values='total_sales', 
                                                                    aggfunc='sum').fillna(0));
plt.title('Динамика роста игровых платформ');
plt.xticks(rotation=45);
plt.xlabel('')
plt.yticks(rotation=0);
plt.ylabel('');

# %% [markdown]
# ### Анализ динамики популярности платформ

# %% [markdown]
# Ранее мы опирались на данные за 2001-2016 год. Это позволило нам сделать вывод о "средней продолжительности жизни" платформы. Учитывая полученное значение, было бы разумным сократить исследуемый период. Но поступим иначе: исключим из исследования более не поддерживаемые платформы, игры для которых в 2016 году уже не продавались.

# %%
actual_platforms = list(data_filtered.pivot_table(index='year_of_release', 
                          columns='platform', 
                          values='total_sales', 
                          aggfunc='sum').loc[2016:].dropna(axis=1).columns)

data_filtered.query('platform in @actual_platforms').pivot_table(index='year_of_release', 
                                                                 columns='platform', 
                                                                 values='total_sales', 
                                                                 aggfunc='sum').plot(figsize=(16, 8), style='-');
plt.xlim([2008, 2016]);
plt.title('Динамика роста игровых платформ');
plt.xlabel('Год выпуска');
plt.ylabel('Количество проданных игр, млн');

# %% [markdown]
# Судя по графику, в 2016 году в упадке были абсолютно все платформы. Скорее всего, это не так, и падение обусловлено тем, что на дату формирования датасета еще не все производители успели отчитаться о полных годовых продажах, и реальные цифры несколько выше. Итак, можно выделить лидеров: платформы Playstation 4 и Xbox One, появивившиеся в 2013 году и способные достичь пика популярности как раз в 2017 году. Тройку лидеров замыкает платформа Nintendo 3DS, еще недавно собиравшая по 40 млн проданных копий в год.
#
# Закономерно падают продажи для платформ-предшественников лидеров, гремевших в конце нулевых. Так, например, до выхода PS4 компания Sony продвигала PS3, Microsoft выпустила XOne на смену Xbox 360, а у Nintendo кроме обновления поколения приставки Wii появилась карманная консоль 3DS.

# %% [markdown]
# Рассмотрим статистику популярности игр для каждой платформы. Для этого отсортируем список актуальных платформ в порядке возрастания медианного числа продаж и удалим с диаграммы размаха выбросы.

# %%
# создание списка медианых продаж для каждой платформы из числа актуальных
#platform_median_sales = [data_filtered.query('platform == @item')['total_sales'].median() for item in actual_platforms]

# Сортировка массива с названиями актуальных платформ по медианным продажам игр
#actual_platforms = [item[1] for item in sorted(zip(platform_median_sales, actual_platforms), reverse=True)]

# %%
actual_platforms_median_sales = (data_filtered.query('platform in @actual_platforms')
                                 .groupby('platform')['total_sales']
                                 .median()
                                 .sort_values(ascending=False))
actual_platforms_median_sales
# Out:
# platform
# X360    0.270
# PS3     0.270
# XOne    0.220
# WiiU    0.210
# PS4     0.195
# Wii     0.190
# 3DS     0.120
# PSV     0.050
# PC      0.040
# Name: total_sales, dtype: float64

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")    
    
    platform_sales = {}
    for platform in actual_platforms_median_sales.index:
        platform_sales[platform] = list(data_filtered.query('platform == @platform')['total_sales'])

    plt.figure(figsize = (16,8))

    plt.boxplot(platform_sales.values(), labels = platform_sales.keys(), showfliers=False);
    plt.title('Медианные продажи для каждой платформы');
    plt.xlabel('');
    plt.ylabel('Количество проданных игр, млн');

# %% [markdown]
# Можно сказать, что игры, выпущенные на платформах Xbox 360 и PS3, проваливались реже всего: половина игр продавались в количестве не менее 250 тыс копий. При этом их более свежие версии - XOne и PS4 - практически не отстают и потенциально могут в ближайшие годы обогнать "родителей". Схожие медианы при таком разном количестве общих продаж говорит о снижении количества игр, доступных для платформ. Если верить полноте датасета, то для новых платформ производители еще не успели выпустить много игр, либо сосредоточились на качестве вместо количества, чтобы поддерживать динамику продаж.

# %% [markdown]
# ### Исследование влияния рейтингов на продажи

# %% [markdown]
# Интуитивно кажется, что между отзывами и продажами должна быть сильная корреляция. И хотя мы не сможем сделать вывод о причинно-следственных связях, установим эту связь.

# %%
for platform in actual_platforms:
    plt.figure(figsize=(16, 5)) # задаём размер сетки
    plt.suptitle('Корреляция между внешними оценками и продажами игр на платформе ' + str(platform) +'\n', y=1.05, size=14)
    gridsize = 40

    ax = plt.subplot(1,2,1)
    data_filtered.query('platform==@platform').plot(x='total_sales', 
                                                    y='critic_score', 
                                                    kind='hexbin',
                                                    gridsize = gridsize,
                                                    ax=ax);
    plt.title('Связь продаж с оценкой критиков', pad=10);
    plt.xlabel('Число проданных копий игры, млн');
    plt.ylabel('Оценка критиков');
    

    ax = plt.subplot(1,2,2)
    data_filtered.query('platform==@platform').plot(x='total_sales', 
                                                    y='user_score', 
                                                    kind='hexbin',
                                                    gridsize = gridsize,
                                                    alpha=1, 
                                                    ax=ax);
    plt.title('Связь продаж с оценкой пользователей', pad=10);
    plt.xlabel('Число проданных копий игры, млн');
    plt.ylabel('Оценка пользователей');
    
    critics_corr = round(data_filtered.query('platform==@platform')["total_sales"].corr(data_filtered.query('platform==@platform')["critic_score"]), 2)
    users_corr = round(data_filtered.query('platform==@platform')["total_sales"].corr(data_filtered.query('platform==@platform')["user_score"]), 2)
    
    plt.figtext(0.1, -0.05, 
    f'Коэффициент корреляции с оценкой критиков: {critics_corr}')
    
    plt.figtext(0.1, -0.1, 
    f'Коэффициент корреляции с оценкой пользователей: {users_corr}')
    
    plt.figtext(0.1, -0.2, ' ')

# %% [markdown]
# Чем крупнее и успешнее платформа, тем сильнее связь ее коммерческого успеха с оценками критиков. Оценки пользователей на продажи влияют гораздо меньше. Здесь можно осторожно выдвинуть гипотезу о причинно-следственной связи: геймеры чаще принимают решение о покупке, опираясь на обзорные статьи и рейтинги, публикуемые профильными источниками. Наверняка через эти каналы производители видеоигр нередко лоббируют свои интересы.

# %% [markdown]
# ### Анализ коммерческой успешности отдельных жанров

# %% [markdown]
# Обратимся к отдельным жанрам и построим распределение продаж в разрезе этого признака.

# %%
# создание списка медианых продаж для каждого жанра
genre_sales = [data_filtered.query('genre == @genre')['total_sales'].median() for genre in data_filtered['genre'].unique()]

# Сортировка массива с названиями жанров по медианным продажам игр
genres = [item[1] for item in sorted(zip(genre_sales, data_filtered['genre'].unique()), reverse=True)]

genre_sales = {}
for genre in genres:
    genre_sales[genre] = list(data_filtered.query('genre == @genre')['total_sales'])
    
plt.figure(figsize = (16,8))

plt.boxplot(genre_sales.values(), labels = genre_sales.keys(), showfliers=False);
plt.title('Медианные продажи для каждого жанра');
plt.xlabel(' ');
plt.ylabel('Количество проданных игр, млн');
# Out:
# /opt/conda/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %% [markdown]
# Видно, что абсолютным лидером являются "стрелялки". Самые плохие показатели у стратегий, головоломок и игр про путешествия.

# %% [markdown]
# ## Составление портрета пользователя каждого региона

# %% [markdown]
# ### Анализ популярности платформ в регионах

# %% [markdown]
# Географические различия накладывают отпечаток на предпочтения пользователей. Чтобы составить портрет современного геймера, ограничим временной промежуток 2013-ым годом и включим в исследование только те платформы, для которых до сих пор выпускаются игры.

# %%
plt.figure(figsize=(16, 8))
plt.suptitle('Суммарные продажи по платформам в регионах')

ax = plt.subplot(1,3,1)
na_top_platforms = (data_filtered
                    .query('platform in @actual_platforms and year_of_release>=2013')
                    .groupby('platform')['north_america_sales']
                    .sum()
                    .sort_values()[::-1][:5])
na_top_platforms.plot(kind='bar', ax=ax);
plt.title('Северная Америка')
ax.set_xlabel('')
plt.xticks(rotation=0)
plt.ylim([0,120]);
plt.ylabel('Количество проданных игр, млн');

ax = plt.subplot(1,3,2)
eu_top_platforms = (data_filtered
                    .query('platform in @actual_platforms and year_of_release>=2013')
                    .groupby('platform')['europe_sales']
                    .sum()
                    .sort_values()[::-1][:5])
eu_top_platforms.plot(kind='bar', ax=ax, color='green');
plt.title('Европа')
ax.set_xlabel('')
plt.xticks(rotation=0)
plt.ylim([0,120]);
plt.ylabel('Количество проданных игр, млн');

ax = plt.subplot(1,3,3)
jp_top_platforms = (data_filtered
                    .query('platform in @actual_platforms and year_of_release>=2013')
                    .groupby('platform')['japan_sales']
                    .sum()
                    .sort_values()[::-1][:5])
jp_top_platforms.plot(kind='bar', ax=ax, color='red');
plt.title('Япония')
ax.set_xlabel('')
plt.xticks(rotation=0)
plt.ylim([0,120]);
plt.ylabel('Количество проданных игр, млн');

# %% [markdown]
# Выделяется патриотичность рынка Японии. Если на Западе сильные позиции занимает Microsoft, то в Японии вся пятерка - отечественные платформы.

# %% [markdown]
# Проведем тот же анализ для жанров видеоигр.

# %%
plt.figure(figsize=(16, 10))
plt.suptitle('Суммарные продажи по жанрам в регионах')
plt.subplots_adjust(wspace=0, hspace=0.4)

ax = plt.subplot(3,1,1)
na_top_genres = (data_filtered
                    .query('platform in @actual_platforms and year_of_release>=2013')
                    .groupby('genre')['north_america_sales']
                    .sum()
                    .sort_values()[-5:])
na_top_genres.plot(kind='barh', ax=ax);
plt.title('Северная Америка')
ax.set_ylabel('')
plt.xlim([0,120]);


ax = plt.subplot(3,1,2)
eu_top_genres = (data_filtered
                    .query('platform in @actual_platforms and year_of_release>=2013')
                    .groupby('genre')['europe_sales']
                    .sum()
                    .sort_values()[-5:])
eu_top_genres.plot(kind='barh', ax=ax, color='green');
plt.title('Европа')
ax.set_ylabel('')
plt.xlim([0,120]);


ax = plt.subplot(3,1,3)
jp_top_genres = (data_filtered
                    .query('platform in @actual_platforms and year_of_release>=2013')
                    .groupby('genre')['japan_sales']
                    .sum()
                    .sort_values()[-5:])
jp_top_genres.plot(kind='barh', ax=ax, color='red');
plt.title('Япония')
ax.set_ylabel('')
plt.xlim([0,120]);

# %% [markdown]
# Структура распределения продаж по жанрам для всех регионов схожа. Выделяется популярность "гонок" в Европе и симуляторов единоборств в Японии. Также в Японии большую долю занимают специфические жанры, аналогов которым в глобальном мире, вероятно, нет, поэтому они помечены как неопределенные".

# %% [markdown]
# Чтобы утвердить некий портрет пользователя в каждом регионе, составим тепловую карту в осях платформа-жанр для каждого региона

# %%
regions_dic = {'Северная Америка':'north_america_sales', 'Европа': 'europe_sales', 'Япония': 'japan_sales'}

for region in regions_dic:
    hhh = (data_filtered.
       query('platform in @actual_platforms and year_of_release>=2013').
       pivot_table(index='genre', 
                   columns='platform', 
                   values = regions_dic[region], 
                   aggfunc = 'median').
       fillna(0))

    plt.subplots(figsize=(16,8)) 
    plt.title('Медианные продажи в регионе ' + region + ', млн', y=1.02, size=14)
    sns.heatmap(hhh, annot=True);
    plt.xlabel('');
    plt.ylabel('');

# %% [markdown]
# Тепловая карта наглядно демонстрирует наиболее успешные сочетания жанров и платформ.

# %% [markdown]
# ### Исследование влияния рейтинга ESRB на продажи в отдельных регионах

# %% [markdown]
# Составим сводную таблицу по долям каждого рейтинга в структуре продаж видеоигр в каждом из регионов.

# %%
rating_to_regions = (data_filtered.pivot_table(index='rating',
                     values = ['north_america_sales', 'europe_sales', 'japan_sales'],
           aggfunc = {'north_america_sales': lambda x: (100*x.sum()/data_filtered['north_america_sales'].sum()).round(1), 
                                      'japan_sales': lambda x: (100*x.sum()/data_filtered['japan_sales'].sum()).round(1), 
                                      'europe_sales': lambda x: (100*x.sum()/data_filtered['europe_sales'].sum()).round(1)}))

rating_to_regions.rename(columns={'europe_sales': 'Продажи в Европе, %', 
                                  'japan_sales': 'Продажи в Японии, %',
                                  'north_america_sales': 'Продажи в Северной Америке, %'}, inplace=True)

rating_to_regions
# Out:
#          Продажи в Европе, %  Продажи в Японии, %  \
# rating
# E                       29.0                 17.6
# E10+                    10.6                  5.9
# M                       21.9                  8.1
# T                       22.3                 18.0
# unknown                 16.2                 50.5
#
#          Продажи в Северной Америке, %
# rating
# E                                 34.3
# E10+                              11.4
# M                                 17.9
# T                                 23.4
# unknown                           13.0

# %% [markdown]
# Видеоигры с неопределенным рейтингом вносят шум в статистику продаж, потому что доля таких игр слишком неоднородна для разных регионов, поэтому, наметив некоторые промежуточные тенденции, построим диаграммы размаха.

# %%
rating_sales_na = {}
rating_sales_eu = {}
rating_sales_jp = {}

for rating in ['M', 'E', 'E10+', 'T']:
    rating_sales_na[rating] = list(data_filtered.query('rating==@rating and not north_america_sales.isna()')['north_america_sales'])
    rating_sales_eu[rating] = list(data_filtered.query('rating==@rating and not europe_sales.isna()')['europe_sales'])
    rating_sales_jp[rating] = list(data_filtered.query('rating==@rating and not japan_sales.isna()')['japan_sales'])
    
plt.figure(figsize=(16,8));
plt.suptitle('Влияние рейтинга на продажи в регионах')

ax = plt.subplot(1,3,1);
plt.boxplot(rating_sales_na.values(), labels=rating_sales_na.keys(), showfliers=False);
plt.title('Северная Америка')
plt.ylabel('Число проданных копий, млн')
plt.ylim([0,0.5])

ax = plt.subplot(1,3,2);
plt.boxplot(rating_sales_eu.values(), labels=rating_sales_eu.keys(), showfliers=False);
plt.title('Европа')
plt.ylabel('Число проданных копий, млн')
plt.ylim([0,0.5])

ax = plt.subplot(1,3,3);
plt.boxplot(rating_sales_jp.values(), labels=rating_sales_jp.keys(), showfliers=False);
plt.title('Япония')
plt.ylabel('Число проданных копий, млн')
plt.ylim([0,0.5]);
# Out:
# /opt/conda/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#
# /opt/conda/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#
# /opt/conda/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning:
#
# ...

# %% [markdown]
# В Америке и Европе лучше всего продаются игры с пометкой "Для взрослых". В Японии - игры для детей и подросткой от 6-13 лет.

# %% [markdown]
# ## Проверка гипотез

# %% [markdown]
# ### Гипотеза 1

# %% [markdown]
# Гипотеза формулируется так: средние пользовательские рейтинги платформ Xbox One и PC одинаковые. Чтобы ее подтвердить или опровергнуть, нужно сформулировать нулевую и альтернативную гипотезы
#
# * $H_0$: пользовательские рейтинги платформ не отличаются
# * $H_1$: между пользовательскими рейтингами есть значимое отличие
#
# Пусть пороговое значение для принятия решения о целесообразности отклонения нулевой гипотезы будет alpha=5%

# %%
pvalue = st.ttest_ind(data_filtered.query('year_of_release>=2013 and platform=="XOne" and not user_score.isna()')['user_score'], 
             data_filtered.query('year_of_release>=2013 and platform=="PC" and not user_score.isna()')['user_score'],
             equal_var = False).pvalue

if pvalue > 0.05:
    print('Пользовательские рейтинги платформ не отличаются, p-value равно', round(pvalue, 2))
else:
    print('Между пользовательскими рейтингами платформ есть значимое отличие, p-value равно', round(pvalue, 6))
# Out:
# Пользовательские рейтинги платформ не отличаются, p-value равно 0.14

# %% [markdown]
# ### Гипотеза 2

# %% [markdown]
# Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
#
# Какой бы ни была формулировка выдвинутой гипотезы, нулевая гипотеза, как правило, говорит о том, что на самом деле различий между выборками нет.
#
# * $H_0$: пользовательские рейтинги жанров Action и Sports не отличаются
# * $H_1$: между пользовательскими рейтингами Action и Sports есть отличие

# %%
pvalue = st.ttest_ind(data_filtered.query('year_of_release>=2013 and genre=="Action" and not user_score.isna()')['user_score'], 
             data_filtered.query('year_of_release>=2013 and genre=="Sports" and not user_score.isna()')['user_score'],
             equal_var = False).pvalue

if pvalue > 0.05:
    print('Пользовательские рейтинги жанров Action и Sports не отличаются, p-value равно', round(pvalue, 20))
else:
    print('Между пользовательскими рейтингами жанров Action и Sports есть значимое отличие, p-value равно', round(pvalue, 20))
# Out:
# Между пользовательскими рейтингами жанров Action и Sports есть значимое отличие, p-value равно 3.6e-19

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# * Выводы данного исследования справедливы настолько, насколько справедливо обобщение имеющегося датасета на весь рынок видеоигр
# * Рынок видеоигр стал бурно развиваться в нулевые и достиг своего пика в 2008-2009 годах. В этот период выпускалось примерно 1400 игр ежегодно.
# * Есть три основных производителя платформ: Sony, Microsoft и Nintendo. Они выпускают сменяющиеся друг друга поколения платформ каждые 8-10 лет
# * Самые перспективные на 2016 год платформы, способные завоевать рынок в 2017 году: Sony Playstation 4, Xbox One, Nintendo 3DS
# * На продажи видеоигры сильно влияет оценка критиков. Пользовательские же оценки роли практически не играют.
# * Глобально по миру срежи жанров лидируют шутеры
# * По данным за 2013-1016 годы в Северной Америке среди популярных платформ лидируют PS4 и XOne (по 80+ млн копий проданных игр), в Европе и Японии абсолютные лидеры PS4 (более 100 млн. копий) и Nintendo 3DS (50+ млн.копий) соответственно.
# * Самые популярные жанры в Северной Америке и Европе совпадают, это экшн, шутеры и спорт. В Японии это экшн и RPG.
# * Помимо перечисленных сочетаний жанров и платформ для всех регионов выделяется популярность карманных приставок Wii.
# * В Америке и Европе лучше всего продаются игры с пометкой "Для взрослых". В Японии - игры для детей и подросткой от 6-13 лет.
